# %%
"""
Created on Thu Oct 24 2021

@author: Jiho Song
"""

"""
A) Introduction:
    This game is based on the movie Frozen(2013). But it is totally fine, 
    even if you haven't seen it yet. This game doesn't need to background 
    knowledge to finish. However, if you already knew the story, it would be 
    helpful. The purpose of the game is to solve the weather problem that 
    came suddenly became winter.
    
    
    Round 1: (Stable) Decide whether or not to help Anna.
    Round 2: (North Mountain) Guess the new character's name.
    Round 3: (Elsa's castle) Decide whether or not to enter the castle.
    Round 4: (Go Arendelle) Decide what to do after taking Anna home.
    Round 5: (Go Anna) Decide who you want to save.
    
B) Known Bugs and/ or Errors:
    None.
    
Frozen website: https://frozen.disney.com/
"""

from sys import exit
import random


# Using input for making players can use their name to play this game. 
# Keep blank spaces after ":" to help users to read easily 
player = input(prompt = "What is your name? : \n")

# Changing user name by using capitalize on looking better.
player = player.capitalize()


# start point is the introduction of the game. And I use a 'defined variable' 
def starting_point():
    print(f"""
My name is {player}. I am an ice harvester and am living in North mountain 
near Arendelle. Today is the coronation of the new queen, and many people have 
repeatedly said about it. Everybody asked me that I would go there, but I 
don't interest in it. So I had decided to go to work. But the sky suddenly 
got dark, and then it snowed. It also began to snow a considerable amount. 
Eventually, I decided to prepare for winter and buy carrots for my reindeer 
friend Sven at a nearby store. But the owner of the store said about ridiculous 
prices. In addition, there was a woman next to me who made me annoying. 
After an argument with the owner, I couldn't buy anything and am resting at 
the stable. The woman came a stable, and she is asking me to go to North mountain. \n
{'-'* 80} \n
    """)

# To help a user to read the introduction easily, insert 'input'.
    input(prompt = "<Press enter to continue>\n")
    stable()

    
# Stage 1
# Stage 1 is a multiple-choice question. the answer is 1.
# If the user chooses the other answers, the user will come back to the question.
def stable():
    print(f"""
And she said she knew how to stop this winter.
What would you like to do?
    1) Go together
    2) Refuse it
    3) Tell her we can't go because Sven is hungry \n
{'-'* 80} \n
    """)   
    
    # Keep blank spaces after ":" to help users to read easily 
    choice = input(prompt = "Your answer is : \n")
    
    
    # I used ‘casefold’ to prevent an error when they type a word to answer.    
    choice = choice.casefold()
   
    # I used 'or' and 'in' to react properly to users answer  
    if choice == '1' or choice == 'go' or 'together' in choice:
        print(f"""
She gave me tools and carrots. And we started for North Mountain. \n
{'-'* 80} \n
        """)
        north_mountain()

    # I used 'or' and 'in' to react properly to users answer          
    elif choice == '2' or 'refuse' in choice:
        print(f"""
She had shown me tools that I wanted to buy and carrots for Sven.
And she asked again. \n
{'-'* 80} \n
        """)
        stable()

    # I used 'or' and 'in' to react properly to users answer          
    elif choice =='3'or choice =='tell her'or choice=="we can't go"or 'hungry' in choice:
        print(f"""
She gave me carrots and asked we could go after finishing his dinner. \n
{'-'* 80} \n
        """)
        
        # using 'random' to choose question 
        situation_list = ['Sven said he is still hungry.',
                         'Sven said he is ready to go']
        
        additional_q = random.choice(situation_list)
        print(additional_q)
        print(f"""
What do you want to do?
    1) Tell her that you couldn't go.
    2) Persuade Sven to go and promise to buy him carrots next time.
        """)
        
        # Keep blank spaces after ":" to help users to read easily 
        choice = input(prompt = "Your answer is : \n")
        
        # I used 'or' and 'in' to react properly to users answer
        if choice == '1' or choice == 'Tell' or "couldn't" in choice:
            print(f"""
I told her that you couldn't go            
            """)
            stable()
        
        # I used 'or' and 'in' to react properly to users answer
        elif choice == '2' or 'Persuade' in choice or 'promise' in choice:
            print(f"""
I told her we could go now            
            """)
            north_mountain()
        
        # Use the else function in case the user's answer cannot be identified.
        else:
            print('Invalid command. Please try again.')
            stable()
        
    # Use the else function in case the user's answer cannot be identified.
    else:
        print('Invalid command. Please try again.')
        stable()

        

# Stage 2
# Stage2 is a short answer question. The user must match the name of the new character.
# Stage2 uses while and the game could be failed if user use all chances.
# Users can try 7 times.

def north_mountain():
    olaf_name = 'Olaf'
    chances = 6
    
    print(f"""
As we went to North Mountain, we introduced each other. She said her name was 
Anna and explained why this winter came. On the way, we heard someone talking, 
and surprisingly, there was a snowman talking.

Surprisingly, Anna seems to know the snowman's name. Let's guess the name.
(You can try {chances + 1} times) \n
{'-'* 80} \n
""")
    
    # use def again since show users question only when they chose the wrong answer.
    def north_mountain_q():
        print(f"""
Surprisingly, Anna seems to know the snowman's name. Let's guess the name.
(You can try {chances + 1} times) \n
{'-'* 80} \n
""")
 
    # Use while to limit the number of attempts.
    # use '[]' to give hint depending on user's answer. 
    while chances >= 0 :
        # Keep blank spaces after ":" to help users to read easily 
        answer = input( prompt = "What do you think his name is? : \n")
        #Use 'capitalize' to avoid an error that will happen because of the user's answer
        answer = answer.capitalize()

        # If users can't match the answer until the chance become 0, the user is failed.
        if chances == 0:
            print(f"""
You spent all chance \n
{'-'* 80} \n
""")
            fail()

        # If users can match the answer, the user goes to the next stage.           
        elif answer == olaf_name:
            print(f"""
{'-'* 80} \n
You are right !! \n
{'-'* 80} \n
                  """)
            elsa_castle()

        # If a user matches 'Ola?', let them know the next alphabet.           
        elif answer[0:3] == 'Ola':
            chances -= 1
            print(f"""
{'-'* 80} \n
Here is the hint. His name is started 'Olaf'. \n
{'-'* 80} \n            
""")
            north_mountain_q()

        # If a user answers 'Ol**?', let them know the next alphabet.            
        elif answer[0:2] == 'Ol':
            chances -= 1
            print(f"""
{'-'* 80} \n
Here is the hint. His name is started 'Ola*'.\n
{'-'* 80} \n
""")
            north_mountain_q()        

        # If a user matches 'O***?', let them know the next alphabet.              
        elif answer[0] == 'O':
            chances -= 1
            print(f"""
{'-'* 80} \n
Here is the hint. His name is started 'Ol**'. \n
{'-'* 80} \n
                  """)
            north_mountain_q()

        # If a user can't matches the first alphabet, let them know the first alphabet.              
        elif answer[0] != 'O':
            chances -= 1
            print(f"""
{'-'* 80} \n
Here is the hint. His name is started 'O***'. \n
{'-'* 80} \n
                  """)
            north_mountain_q()

        # The purpose of 'else' is to prevent an error            
        else:
            print("Invalid command. Please try again.")
            north_mountain_q()

            
#stage 3 
# stage3 is a multiple-choice question. and a user can fail the game depending on their choice.

def elsa_castle():
    print(f"""
Due to the help of Olaf, we arrived at Elsa's castle. 
Anna is trying to go into the castle alone.\n
{'-'* 80} \n

What would you like to say? 
1) It looks dangerous. Let's enter together.
2) I will wait in front of the castle.
3) My task is over. Goodbye.\n
""")
    
    # next part of game
    

# To show the question only after answering, I made an additional defined variable     
    def elsa_castle_q():
        print(f"""
Anna is trying to go into the castle alone

What would you like to say? 
1) It looks dangerous. Let's enter together.
2) I will wait in front of the castle.
3) My task is over. Goodbye.\n
{'-'* 80} \n
    """)

        
    while True:
        # Keep blank spaces after ":" to help users to read easily
        # Use 'casefold' to avoid an error that will happen because of the user's answer 
        q3_answer = input(prompt = "Choose your answer : \n")
        q3_answer = q3_answer.casefold()

        
        # I used 'or' and 'in' to react properly to users answer            
        if q3_answer =="1" or 'dangerous' in q3_answer or 'together' in q3_answer:
            print(f"""
Anna said she wants to talk with her sister alone. \n
{'-'* 80} \n
""")
            elsa_castle_q()

        # I used 'or' and 'in' to react properly to users answer               
        elif q3_answer =="2" or 'wait' in q3_answer or 'castle' in q3_answer:
            print(f"""
Anna asked us to give her a moment. \n
{'-'* 80} \n
""")
            go_Arendelle()

        # I used 'or' and 'in' to react properly to users answer               
        elif q3_answer =='3' or 'over' in q3_answer or 'bye' in q3_answer:
            print(f"""
Anna is saying she wants me to wait for her until she finishes talking with Elsa.
Are you sure to go back? (Y/N) \n
{'-'* 80} \n
""")
            # Keep blank spaces after ":" to help users to read easily.
            # Use 'casefold' to avoid an error that will happen because of the user's answer
            q3_elif_answer_2 = input(prompt="What would you like to do? : \n")
            q3_elif_answer_2 = q3_elif_answer_2.casefold()

            
            
            # I used 'or' and 'in' for react properly about users answer.
            # if the user choose yes, the user will fail the game.
            if q3_elif_answer_2 =='y' or 'yes' in q3_elif_answer_2:
                print(f"""
I came back home, but it is still winter \n
{'-'* 80} \n
                """)
                fail()

                
            # if a user chooses no, the user goes back to the first question..    
            elif q3_elif_answer_2 == 'n' or 'no' in q3_elif_answer_2:
                print(f"""
I'm worried about leave Anna alone. Let's go back.
A big snowman blocks me when I decide go back to Anna.
And he told me that I can go to Anna after I answer his question. \n
{'-'* 80} \n
                  """)
              
                # make a list for random questions           
                q_list = ['Am I a man or a woman?',
                         'How many brothers and sisters I have?',
                          'How old am I?']
                
                # choose a question by using random
                question = random.choice(q_list)
                
                # A question for question list 0
                if question == q_list[0]:
                    print(question)
                    print(f"""
1) A man
2) A woman
3) I don't know \n                    
                    """)
                    
                    # make def for user who chose wrong answers     
                    def snowman0():
                        print(f"""
{q_list[0]} \n
1) A man
2) A woman
3) I don't know \n     
                        """)
                    # while loop to repeat the question for users who chose wrong answers    
                    while True: 
                    
                        # Keep blank spaces after ":" to help users to read easily 
                        choice = input(prompt = "Your answer is :  \n")  
    
                        # I used ‘casefold’ to prevent an error when they type a word to answer.    
                        choice = choice.casefold()
                    
                # I used 'or' and 'in' for react properly about users answer.
                        if choice == '1' or 'man' in choice:
                            print(f"""
Are you sure? I don't think I am a man \n       
                        """)
                            snowman0()
                        
                        # I used 'or' and 'in' for react properly about users answer.
                        elif choice == '2' or 'woman' in choice:
                            print(f"""
Are you sure? I don't think I am a woman \n       
                        """)
                            snowman0()
                        
                        # I used 'or' and 'in' for react properly about users answer.
                        # break need to go back to elsa_castle_q
                        elif choice == '3' or 'know' in choice:
                            print(f"""
I don't know my gender, too \n       
                        """)
                            elsa_castle_q()
                            break
                        
                        # The purpose of 'else' is to prevent an error
                        else : 
                            print('Invalid command. Please try again.')
                            snowman0()
                        
                # A question for question list 1        
                if question == q_list[1]:
                    print(question)
                    print(f"""
1) A brother
2) Two brothers
3) More than three brothers \n                    
                    """)
                    
                    
                     # make def for user who chose wrong answers 
                    def snowman1():
                        print(f"""
{q_list[1]} \n
1) A brother
2) Two brothers
3) More than three brothers \n     
                        """)
                    
                    # while loop to repeat the question for users who chose wrong answers  
                    while True:                    
                        # Keep blank spaces after ":" to help users to read easily 
                        choice = input(prompt = "Your answer is :  \n")

                        # I used ‘casefold’ to prevent an error when they type a word to answer.    
                        choice = choice.casefold()
                    
                        # I used 'or' and 'in' for react properly about users answer.
                        # break need to go back to elsa_castle_q
                        if choice == '1' or 'one' in choice:
                            print(f"""
You are right. I heard I have a brother who is Olaf. \n       
                        """)
                            elsa_castle_q()
                            break
                            
                       # I used 'or' and 'in' for react properly about users answer.     
                        elif choice == '2' or 'two' in choice:
                            print(f"""
Are you sure? \n       
                        """)
                            snowman1()
                      
                        # I used 'or' and 'in' for react properly about users answer.
                        elif choice == '3' or 'more' in choice:
                            print(f"""
Don't you think that is too much?  \n       
                        """)
                            snowman1()
                        
                        # The purpose of 'else' is to prevent an error
                        else : 
                            print('Invalid command. Please try again.')
                            snowman1()
                        

                # A question for question list 2
                if question == q_list[2]:
                    print(question)
                    print(f"""
1) 1 years old
2) I have lived in this mountain over 100 years
3) I don't know \n                    
                    """)
                                        
                     # make def for user who chose wrong answers 
                    def snowman2():
                        print(f"""
{q_list[2]} \n
1) 1 years old
2) I have lived in this mountain over 100 years
3) I don't know \n     
                        """)
                    
                    # while loop to repeat the question for users who chose wrong answers  
                    while True: 
                        
                        # Keep blank spaces after ":" to help users to read easily 
                        choice = input(prompt = "Your answer is :  \n")
    
    
                        # I used ‘casefold’ to prevent an error when they type a word to answer.    
                        choice = choice.casefold()
                    
                        # I used 'or' and 'in' for react properly about users answer.
                        # break need to go back to elsa_castle_q
                        if choice == '1' or 'one' in choice:
                            print(f"""
You are right!!. Elsa made me \n       
                        """)
                            elsa_castle_q()
                            break
                       
                        # I used 'or' and 'in' for react properly about users answer.
                        elif choice == '2' or '100' in choice:
                            print(f"""
Are you sure? \n       
                        """)
                            snowman2()
                       
                        # I used 'or' and 'in' for react properly about users answer.
                        elif choice == '3' or 'know' in choice:
                            print(f"""
You chose a wrong answer. Think more! \n       
                        """)
                            snowman2()
                            
                        # The purpose of 'else' is to prevent an error
                        else : 
                            print('Invalid command. Please try again.')
                            snowman2()

            
            # The purpose of 'else' is to prevent an error
            else:
                print('Invalid command. Please try again.')
                elsa_castle_q()

            
#stage 4 
# Stage4 is a multiple-choice question. the answer is 2.
# If the user chooses the other answers, the user will come back to the question.

def go_Arendelle():
    print(f"""
We were all kicked out of the castle. Anna has been sick since then. 
Trolls said that true love is needed to cure Anna. I decided to go back to the 
castle to save her, and now I'm in front of the gate. \n
{'-'* 80} \n

What would you like to do?
1) I'm going in together because I'm worried.
2) Since we've done our job, let's go back.
3) Since we're here, let's buy something and go.
    """)
    
    # To show the question only after answering, I made an additional defined variable      
    def go_Arendelle_q():
        print(f"""
What would you like to do?
1) I'm going in together because I'm worried.
2) Since we've done our job, let's go back.
3) Since we're here, let's buy something and go.  \n
{'-'* 80} \n
        """)

    while True:
        # Keep blank spaces after ":" to help users to read easily.
        # Use 'casefold' to avoid an error that will happen because of the user's answer 
        q4_answer = input(prompt = "Choose your answer :   \n")
        q4_answer = q4_answer.casefold()
        
        # I used 'or' and 'in' to react properly to users answer .
        if q4_answer =="1" or 'worried' in q4_answer or 'together' in q4_answer:
            print(f"""
The people who work in the castle say they'll take care of her. \n
{'-'* 80} \n
""")
            go_Arendelle_q()
        
        # I used 'or' and 'in' to react properly to users answer .
        elif q4_answer =="2" or 'done' in q4_answer or 'back' in q4_answer:
            print(f"""
Sven and I decided to go back to our place. \n
{'-'* 80} \n
""")
            go_anna() 
        
        # I used 'or' and 'in' to react properly to users answer 
        elif q4_answer =="3" or 'here' in q4_answer or 'something' in q4_answer:
            print(f"""
All stores close because of snow. \n
{'-'* 80} \n
""")
            go_Arendelle_q()
        
        # The purpose of 'else' is to prevent an error 
        else:
            print('Invalid command. Please try again. \n')
            go_Arendelle_q()

            
# stage 5
# stage 5 is the final stage and users can choose the ending.

def go_anna():
    print(f"""
While going home, Sven blocked me and said we needed to go back to Arendelle. 
During our argument, I looked back at Arendelle to pray for Anna. Suddenly, 
a cloud that seemed dangerous appeared up above there.

What would you like to do?
1) Go to Arendelle
2) It looks dangerous. Let's watch \n
{'-'* 80} \n
    """)
    
    # To show the question only after answering, I made an additional defined variable   
    def go_anna_q():
        print(f"""
What would you like to do?
1) Go to Arendelle
2) It looks dangerous. Let's watch. \n
{'-'* 80} \n
    """)
        
         
        
    # Keep blank spaces after ":" to help users to read easily.
    # Use 'casefold' to avoid an error that will happen because of the user's answer 
    while True:
        q5_answer = input(prompt = "Choose your answer :   \n")
        q5_answer = q5_answer.casefold()
        
         # I used 'or' and 'in' to react properly to users answer 
        if q5_answer =="1" or 'go' in q5_answer or 'arendelle' in q5_answer:
            print(f"""
The frozen lake begins to crack while running. It's dangerous to run. 
Should I run more?. (Y/N) \n
{'-'* 80} \n
""")
            
            # To show the question only after answering, I made an additional defined variable  
            def go_anna_1_1():
                  print(f"""
The frozen lake begins to crack while running. It's dangerous to run. 
Should I run more?. (Y/N) \n
{'-'* 80} \n
""")
            # Keep blank spaces after ":" to help users to read easily.
            # Use 'casefold' to avoid an error that will happen because of the user's answer      
            q5_answer_1 = input(prompt = "Choose your answer :   \n")
            q5_answer_1 = q5_answer_1.casefold()
            
            # I used 'or' and 'in' for react properly about users answer.
            if  q5_answer_1 == 'y' or 'yes' in q5_answer_1:
                print(f"""
As I am running, I saw a man running to Elsa with a knife. 
Anna is standing on the other side. Who should I go to? 
1) Anna
2) Elsa \n
{'-'* 80} \n
                  """)
                
                # Keep blank spaces after ":" to help users to read easily.
                # Use 'casefold' to avoid an error that will happen because of the user's answer
                q5_answer_2 = input(prompt = "Choose your answer :   \n")
                q5_answer_2 = q5_answer_2.casefold()
                
                 # I used 'or' and 'in' to react properly to users answer 
                if q5_answer_2 == '1' or 'anna' in q5_answer_2:
                    ending_anna()
                
                 # I used 'or' and 'in' to react properly to users answer 
                elif q5_answer_2 == '2' or 'elsa' in q5_answer_2:
                    ending_elsa()
                
                # The purpose of 'else' is to prevent an error
                else:
                    print('Invalid command. Please try again.')
                    go_anna_1_1()
            
             # I used 'or' and 'in' to react properly to users answer 
            elif q5_answer_1 == 'n' or 'no' in q5_answer_1:
                print(f"""
I think I can see Anna when I'm about to go back. \n
{'-'* 80} \n
                """)
                go_anna_q()
            
            # The purpose of 'else' is to prevent an error
            else:
                print('Invalid command. Please try again.')
                go_anna_q()
                  
         # I used 'or' and 'in' to react properly to users answer          
        elif q5_answer =="2" or 'dangerous' in q5_answer or 'watch' in q5_answer:
            print(f"""
I'm worried about Anna. Let's go \n
{'-'* 80} \n
""")        
            go_anna_q()
        
        # The purpose of 'else' is to prevent an error
        else: 
            print('Invalid command. Please try again.')
            go_anna_q()

            
# Anna Ending 
# If a user chooses Anna, they will see this
def ending_anna():
    print(f"""
Anna also found the man and ran to save Elsa. The moment the man swings his 
sword, Anna throws herself to save Elsa and becomes ice. However, Anna comes 
back to life with Elsa's love. Elsa realized how to control her abilities with 
the power of love, and spring comes again in Arendelle. \n
{'*' *40} \n
""")
    input(prompt = "<Press enter to continue>\n")    
    ending()

    
 # Elsa Ending
# If a user chooses Elsa, they will see this
def ending_elsa():
    print(f"""
To save Elsa, I ran and took away the sword held by the man. After saving Elsa, 
I went to Anna, but Anna was already frozen. I told Elsa what Anna had been 
through, and Elsa realized that Anna liked her. Elsa realized how the power 
of love controls her ability. Elsa makes spring come again in Arendelle. \n    
{'*' *40} \n
    """)
    input(prompt = "<Press enter to continue>\n")
    ending()

# choose job 
# The ending is changed by user's answer.
# Keep blank spaces after ":" to help users to read easily.
# I used 'casefold' to put the user's answer in the sentence. 
def ending():
    ending_answer = input(prompt='What job do you want to be? \n ')
    ending_answer = ending_answer.casefold()
                  
    print(f"""
Spring has come again in Arendelle, but my ice business has become difficult. 
Upon hearing the news, Elsa appointed me Honorary {ending_answer} for Arendelle. 
Thanks to her, I settled down in the village.

***** Thanks for playing ***** 

{'*' *40}
    """)
    exit(0)

# Fail
# If the user chooses the wrong answer, the game is over. This defined variable exists for the situation.
def fail():
    print(f"""
{'*' *40}
  ________                                                  
 /  _____/_____    _____   ____     _______  __ ___________ 
/   \  ___\__  \  /     \_/ __ \   /  _ \  \/ // __ \_  __ \
\    \_\  \/ __ \|  Y Y  \  ___/  (  <_> )   /\  ___/|  | \/
 \______  (____  /__|_|  /\___  >  \____/ \_/  \___  >__|   
        \/     \/      \/     \/                   \/       
        
***** Thanks for playing ***** 

{'*' *40}
    """)
    exit(0)
            
starting_point()
